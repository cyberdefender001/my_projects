# %%
pip install -U spacy
# Out:
# Collecting spacy
#   Downloading spacy-3.5.3-cp310-cp310-macosx_10_9_x86_64.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 4.4 MB/s eta 0:00:0000:0100:010m
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.8-py3-none-any.whl (17 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.4-py3-none-any.whl (11 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting pathy>=0.10.0
#   Downloading pathy-0.10.1-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from spacy) (22.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from spacy) (5.2.1)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.7-cp310-cp310-macosx_10_9_x86_64.whl (32 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from spacy) (4.64.1)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.9-cp310-cp310-macosx_10_9_x86_64.whl (18 kB)
# Requirement already satisfied: jinja2 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from spacy) (3.1.2)
# Collecting thinc<8.2.0,>=8.1.8
#   Downloading thinc-8.1.10-cp310-cp310-macosx_10_9_x86_64.whl (859 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 859.1/859.1 kB 6.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy>=1.15.0 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from spacy) (1.23.5)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.6/181.6 kB 4.8 MB/s eta 0:00:00
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.6-cp310-cp310-macosx_10_9_x86_64.whl (491 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.9/491.9 kB 5.2 MB/s eta 0:00:0000:0100:01
# Collecting pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4
#   Downloading pydantic-1.10.8-cp310-cp310-macosx_10_9_x86_64.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 6.6 MB/s eta 0:00:0000:0100:01
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.8-cp310-cp310-macosx_10_9_x86_64.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from spacy) (65.6.3)
# Collecting wasabi<1.2.0,>=0.9.1
#   Downloading wasabi-1.1.2-py3-none-any.whl (27 kB)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from spacy) (2.28.1)
# Collecting typer<0.8.0,>=0.3.0
#   Downloading typer-0.7.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Collecting confection<1.0.0,>=0.0.1
#   Downloading confection-0.0.4-py3-none-any.whl (32 kB)
# Collecting blis<0.8.0,>=0.7.8
#   Downloading blis-0.7.9-cp310-cp310-macosx_10_9_x86_64.whl (6.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 5.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from typer<0.8.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from jinja2->spacy) (2.1.1)
# Installing collected packages: cymem, wasabi, typer, spacy-loggers, spacy-legacy, pydantic, murmurhash, langcodes, catalogue, blis, srsly, preshed, pathy, confection, thinc, spacy
# Successfully installed blis-0.7.9 catalogue-2.0.8 confection-0.0.4 cymem-2.0.7 langcodes-3.3.0 murmurhash-1.0.9 pathy-0.10.1 preshed-3.0.8 pydantic-1.10.8 spacy-3.5.3 spacy-legacy-3.0.12 spacy-loggers-1.0.4 srsly-2.4.6 thinc-8.1.10 typer-0.7.0 wasabi-1.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.2-cp310-cp310-macosx_10_9_x86_64.whl (160 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.5/160.5 kB 698.0 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy>=1.6.1 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: matplotlib in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from wordcloud) (3.7.0)
# Requirement already satisfied: pillow in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: cycler>=0.10 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (22.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np 
import re 
import string
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
import spacy

from sklearn import metrics
from sklearn.metrics import confusion_matrix,roc_auc_score,classification_report
from sklearn.compose import ColumnTransformer

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier,ExtraTreesClassifier
from sklearn.linear_model import RidgeClassifier,SGDClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB

# %%
column_names=['Tweet_ID','Entity','Sentiment','Tweet_content']

train = pd.read_csv("twitter_training.csv",
                    sep=',',names=column_names)


validation = pd.read_csv("twitter_validation.csv",
                    sep=',',names=column_names)

# %%
train.head()
# Out:
#    Tweet_ID       Entity Sentiment  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
#
#                                        Tweet_content
# 0  im getting on borderlands and i will murder yo...
# 1  I am coming to the borders and I will kill you...
# 2  im getting on borderlands and i will kill you ...
# 3  im coming on borderlands and i will murder you...
# 4  im getting on borderlands 2 and i will murder ...

# %%
validation.head()
# Out:
#    Tweet_ID     Entity   Sentiment  \
# 0      3364   Facebook  Irrelevant
# 1       352     Amazon     Neutral
# 2      8312  Microsoft    Negative
# 3      4371      CS-GO    Negative
# 4      4433     Google     Neutral
#
#                                        Tweet_content
# 0  I mentioned on Facebook that I was struggling ...
# 1  BBC News - Amazon boss Jeff Bezos rejects clai...
# 2  @Microsoft Why do I pay for WORD when it funct...
# 3  CSGO matchmaking is so full of closet hacking,...
# 4  Now the President is slapping Americans in the...

# %%
# information of the dataset
print(f"Train dataset shape {train.shape}")
print(f"Validation dataset shape {validation.shape}")
# Out:
# Train dataset shape (74682, 4)
# Validation dataset shape (1000, 4)

# %%
# checking nan values 
print("\t\t\tTrain dataset")
print(train.isna().sum())
print("*"*40)
print("\t\t\tValidation dataset")
print(validation.isna().sum())
# Out:
# 			Train dataset
# Tweet_ID           0
# Entity             0
# Sentiment          0
# Tweet_content    686
# dtype: int64
# ****************************************
# 			Validation dataset
# Tweet_ID         0
# Entity           0
# Sentiment        0
# Tweet_content    0
# dtype: int64

# %%
# checking duplicated values
print("\t\t\tTrain dataset")
print(train.duplicated().sum())
print("*"*40)
print("\t\t\tValidation dataset")
print(validation.duplicated().sum())
# Out:
# 			Train dataset
# 2700
# ****************************************
# 			Validation dataset
# 0

# %%
# remove dupicate and nan values
train.dropna(inplace=True)
train.drop_duplicates(inplace=True)

# %%
def remove_urls(text):
    """Berilgan matndan URL larini o'chiradi"""
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    return url_pattern.sub(r'', text)


def remove_emojis(text):
    """Berilgan matndan emojilarni o'chiradi"""
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emojilar
                               u"\U0001F300-\U0001F5FF"  # simvollar va diagrammalar
                               u"\U0001F680-\U0001F6FF"  # transport va turli joylar
                               u"\U0001F1E0-\U0001F1FF"  # davlat bayroqlari
                               u"\U00002702-\U000027B0"  # dingbats
                               u"\U000024C2-\U0001F251"  # alamatchilik belgilari
                               "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

# %%
train['Tweet_content'] = train['Tweet_content'].apply(lambda x: remove_emojis(x))
train['Tweet_content'] = train['Tweet_content'].apply(lambda x: remove_urls(x))

validation['Tweet_content'] = validation['Tweet_content'].apply(lambda x: remove_emojis(x))
validation['Tweet_content'] = validation['Tweet_content'].apply(lambda x: remove_urls(x))

# %%
train['text_lens']=train['Tweet_content'].apply(lambda x: len(x))
validation['text_lens']=validation['Tweet_content'].apply(lambda x: len(x))

# %%
fig , ax = plt.subplots(1,2,figsize=(12,6))

ax[0].pie(train['Sentiment'].value_counts(),labels=train['Sentiment'].value_counts().index,autopct='%.f%%')
ax[1].pie(validation['Sentiment'].value_counts(),labels=validation['Sentiment'].value_counts().index,autopct='%.f%%')

fig.suptitle("Proportions of target classes")
ax[0].set_title("Train dataset")
ax[1].set_title("Validation dataset")

plt.show()

# %%
fig ,ax = plt.subplots(2,1,figsize=(14,16))

sns.kdeplot(data=train,x='text_lens',hue='Sentiment',ax=ax[0])
sns.kdeplot(data=validation,x='text_lens',hue='Sentiment',ax=ax[1])

fig.suptitle("Length of tweets in datasets")
ax[0].set_title("Train dataset")
ax[1].set_title("Validation dataset")

plt.show()

# %%
#Count information per category
data1=train.groupby(by=["Entity","Sentiment"]).count().reset_index()
data1.head()
# Out:
#         Entity   Sentiment  Tweet_ID  Tweet_content  text_lens
# 0       Amazon  Irrelevant       185            185        185
# 1       Amazon    Negative       565            565        565
# 2       Amazon     Neutral      1197           1197       1197
# 3       Amazon    Positive       302            302        302
# 4  ApexLegends  Irrelevant       185            185        185

# %%
#Figure of comparison per branch
plt.figure(figsize=(20,6))
sns.barplot(data=data1,x="Entity",y="Tweet_ID",hue='Sentiment')
plt.xticks(rotation=90)
plt.xlabel("Brand")
plt.ylabel("Number of tweets")
plt.grid()
plt.title("Distribution of tweets per Branch and Type")
plt.show()

# %%
word_cloud_text = ''.join(train[train["Sentiment"]=="Positive"].Tweet_content)
wordcloud = WordCloud(
    max_font_size=100,
    max_words=100,
    background_color="black",
    scale=10,
    width=800,
    height=800
).generate(word_cloud_text)
#Figure properties
plt.figure(figsize=(6,6))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
word_cloud_text_negative = ''.join(train[train["Sentiment"]=="Negative"].Tweet_content)
wordcloud_negative = WordCloud(
    max_font_size=100,
    max_words=100,
    background_color="black",
    scale=10,
    width=800,
    height=800
).generate(word_cloud_text_negative)
#Figure properties
plt.figure(figsize=(6,6))
plt.imshow(wordcloud_negative, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
word_cloud_text = ''.join(train[train["Sentiment"]=="Neutral"].Tweet_content)
wordcloud = WordCloud(
    max_font_size=100,
    max_words=100,
    background_color="black",
    scale=10,
    width=800,
    height=800
).generate(word_cloud_text)
#Figure properties
plt.figure(figsize=(6,6))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
word_cloud_text = ''.join(train[train["Sentiment"]=="Irrelevant"].Tweet_content)
wordcloud = WordCloud(
    max_font_size=100,
    max_words=100,
    background_color="black",
    scale=10,
    width=800,
    height=800
).generate(word_cloud_text)
#Figure properties
plt.figure(figsize=(6,6))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
fig , ax = plt.subplots(1,2,figsize=(16,6))

sns.boxplot(data=train,x='text_lens',ax=ax[0])
sns.boxplot(data=validation,x='text_lens',ax=ax[1])

ax[0].set_title("Train dataset")
ax[1].set_title("Validation dataset")

plt.show()

# %%
def remove_outlier(df_in, col_name):
    q1 = df_in[col_name].quantile(0.25)
    q3 = df_in[col_name].quantile(0.75)
    iqr = q3-q1 #Interquartile range
    fence_low  = q1-1.5*iqr
    fence_high = q3+1.5*iqr
    df_out = df_in.loc[(df_in[col_name] > fence_low) & (df_in[col_name] < fence_high)]
    return df_out

#remove outliers
train = remove_outlier(train,'text_lens')

# %%
import spacy.cli
spacy.cli.download("en_core_web_lg")
nlp = spacy.load("en_core_web_lg")
# Out:
# Collecting en-core-web-lg==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.5.0/en_core_web_lg-3.5.0-py3-none-any.whl (587.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from en-core-web-lg==3.5.0) (3.5.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (8.1.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (4.64.1)
# Requirement already satisfied: numpy>=1.15.0 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.28.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.10.8)
# Requirement already satisfied: jinja2 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.1.2)
# Requirement already satisfied: setuptools in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (67.8.0)
# Requirement already satisfied: packaging>=20.0 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (22.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (4.4.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2022.12.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.1.1)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.5.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
pip install -U pip setuptools wheel
# Out:
# Requirement already satisfied: pip in /Users/asadbek/anaconda3/lib/python3.10/site-packages (23.1.2)
# Requirement already satisfied: setuptools in /Users/asadbek/anaconda3/lib/python3.10/site-packages (67.8.0)
# Requirement already satisfied: wheel in /Users/asadbek/anaconda3/lib/python3.10/site-packages (0.40.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install PyQt5
# Out:
# Requirement already satisfied: PyQt5 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (5.15.9)
# Requirement already satisfied: PyQt5-sip<13,>=12.11 in /Users/asadbek/anaconda3/lib/python3.10/site-packages/PyQt5_sip-12.11.0-py3.10-macosx-10.9-x86_64.egg (from PyQt5) (12.11.0)
# Requirement already satisfied: PyQt5-Qt5>=5.15.2 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from PyQt5) (5.15.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install PyQtWebEngine
# Out:
# Collecting PyQtWebEngine
#   Downloading PyQtWebEngine-5.15.6-cp37-abi3-macosx_10_13_x86_64.whl (187 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.6/187.6 kB 754.9 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: PyQt5-sip<13,>=12.11 in /Users/asadbek/anaconda3/lib/python3.10/site-packages/PyQt5_sip-12.11.0-py3.10-macosx-10.9-x86_64.egg (from PyQtWebEngine) (12.11.0)
# Collecting PyQtWebEngine-Qt5>=5.15.0 (from PyQtWebEngine)
#   Downloading PyQtWebEngine_Qt5-5.15.2-py3-none-macosx_10_13_intel.whl (77.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 MB 2.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: PyQt5>=5.15.4 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from PyQtWebEngine) (5.15.9)
# Requirement already satisfied: PyQt5-Qt5>=5.15.2 in /Users/asadbek/anaconda3/lib/python3.10/site-packages (from PyQt5>=5.15.4->PyQtWebEngine) (5.15.2)
# Installing collected packages: PyQtWebEngine-Qt5, PyQtWebEngine
# Successfully installed PyQtWebEngine-5.15.6 PyQtWebEngine-Qt5-5.15.2
# Note: you may need to restart the kernel to use updated packages.

# %%
#nlp=spacy.load('en_core_web_sm')

def preprocess(text):
    doc = nlp(text)
    filtered_tokens=[]
    for token in doc:
        if not token.is_stop and not token.is_punct:
            filtered_tokens.append(token.lemma_)
    return " ".join(filtered_tokens)
    

train['preprocessed_text']=train['Tweet_content'].apply(lambda x: preprocess(x))
validation['preprocessed_text']=validation['Tweet_content'].apply(lambda x: preprocess(x))

# %%
from sklearn.model_selection import train_test_split

X_train ,X_test , y_train, y_test = train_test_split(
    train[['preprocessed_text']],
    train[['Sentiment']],
    test_size=0.2,
    random_state=42
)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer= TfidfVectorizer()

X_train_vect= vectorizer.fit_transform(X_train['preprocessed_text'])
X_test_vect= vectorizer.transform(X_test['preprocessed_text'])

y_train=y_train['Sentiment'].map({"Positive":0,"Negative":1,"Neutral":2,"Irrelevant":3})
y_test=y_test['Sentiment'].map({"Positive":0,"Negative":1,"Neutral":2,"Irrelevant":3})

# %%
validation_X = vectorizer.transform(validation['preprocessed_text'])
validation_y = validation['Sentiment'].map({"Positive":0,"Negative":1,"Neutral":2,"Irrelevant":3})

# %%
model = MultinomialNB()
model.fit(X_train_vect,y_train)
y_predict= model.predict(X_test_vect)
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.80      0.74      3900
#            1       0.65      0.89      0.75      4238
#            2       0.84      0.64      0.73      3518
#            3       0.94      0.43      0.59      2516
#
#     accuracy                           0.72     14172
#    macro avg       0.78      0.69      0.70     14172
# weighted avg       0.76      0.72      0.72     14172

# %%
model = RandomForestClassifier()
model.fit(X_train_vect,y_train)
y_predict= model.predict(X_test_vect)

print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.94      0.89      3900
#            1       0.92      0.92      0.92      4238
#            2       0.93      0.90      0.91      3518
#            3       0.97      0.86      0.91      2516
#
#     accuracy                           0.91     14172
#    macro avg       0.92      0.90      0.91     14172
# weighted avg       0.91      0.91      0.91     14172

# %%
model_extra = ExtraTreesClassifier()
model_extra.fit(X_train_vect,y_train)
y_predict= model_extra.predict(X_test_vect)
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.95      0.91      3900
#            1       0.94      0.93      0.94      4238
#            2       0.95      0.91      0.93      3518
#            3       0.98      0.88      0.93      2516
#
#     accuracy                           0.92     14172
#    macro avg       0.93      0.92      0.92     14172
# weighted avg       0.93      0.92      0.92     14172

# %%
y_predict= model_extra.predict(validation_X)
print(classification_report(validation_y,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96       277
#            1       0.95      0.97      0.96       266
#            2       0.97      0.95      0.96       285
#            3       0.99      0.93      0.96       172
#
#     accuracy                           0.96      1000
#    macro avg       0.96      0.96      0.96      1000
# weighted avg       0.96      0.96      0.96      1000

# %%
import pickle
with open('model_extra.pkl', 'wb') as file:
    pickle.dump(model_extra, file)
    
with open('vectorizer.pkl', 'wb') as file:
    pickle.dump(vectorizer, file)

# %%
with open('model_extra.pkl', 'rb') as file:
    mod = pickle.load(file)

# %%
train.to_csv("train_data.csv")
validation.to_csv('validation_data.csv')

# %%
text1="Are uyou kidding me? How about CONSIDERING working ANYwhere else? Jeezus."
text_final = vectorizer.transform([text1])

predict = model_extra.predict(text_final)

# %%
predict
# Out:
# array([1])
